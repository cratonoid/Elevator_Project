# %%
import pandas as pd
from sklearnex import patch_sklearn
patch_sklearn()

# Load data
data = pd.read_csv("Book2.csv")

# Preprocessing

df = pd.DataFrame(data)


#average data for lift A
avg_A2 = df.loc[df['A_Floor'] == 2, 'A_Timings'].mean()
avg_A4 = df.loc[df['A_Floor'] == 4, 'A_Timings'].mean()
avg_A6 = df.loc[df['A_Floor'] == 6, 'A_Timings'].mean()
avg_A8 = df.loc[df['A_Floor'] == 8, 'A_Timings'].mean()
avg_A9 = df.loc[df['A_Floor'] == 9, 'A_Timings'].mean()
fixed_A = df['A_Fixed'].mean()
avg_cap_A = df['A_Lift_capacity'].mean()

 
#average data for lift B
avg_B1 = df.loc[df['B_Floor'] == 1, 'B_Timings'].mean()
avg_B3 = df.loc[df['B_Floor'] == 3, 'B_Timings'].mean()
avg_B5 = df.loc[df['B_Floor'] == 5, 'B_Timings'].mean()
avg_B7 = df.loc[df['B_Floor'] == 7, 'B_Timings'].mean()
avg_B9 = df.loc[df['B_Floor'] == 9, 'B_Timings'].mean()
fixed_B = df['B_Fixed'].mean()
avg_cap_B= df['B_Lift_capacity'].mean()


#average data for lift C
avg_C2 = df.loc[df['C_Floor'] == 2, 'C_Timings'].mean()
avg_C4 = df.loc[df['C_Floor'] == 4, 'C_Timings'].mean()
avg_C6 = df.loc[df['C_Floor'] == 6, 'C_Timings'].mean()
avg_C8 = df.loc[df['C_Floor'] == 8, 'C_Timings'].mean()
avg_C9 = df.loc[df['C_Floor'] == 9, 'C_Timings'].mean()
fixed_C = df['C_Fixed'].mean()
avg_cap_C = df['B_Lift_capacity'].mean()


#average data for lift D
avg_D1 = df.loc[df['D_Floor'] == 1, 'D_Timings'].mean()
avg_D3 = df.loc[df['D_Floor'] == 3, 'D_Timings'].mean()
avg_D5 = df.loc[df['D_Floor'] == 5, 'D_Timings'].mean()
avg_D7 = df.loc[df['D_Floor'] == 7, 'D_Timings'].mean()
avg_D9 = df.loc[df['D_Floor'] == 9, 'D_Timings'].mean()
fixed_D = df['D_Fixed'].mean()
avg_cap_D = df['D_Lift_capacity'].mean()



#average data for lift E
avg_E1 = df.loc[df['E_Floor'] == 1, 'E_Timings'].mean()
avg_E2 = df.loc[df['E_Floor'] == 2, 'E_Timings'].mean()
avg_E3 = df.loc[df['E_Floor'] == 3, 'E_Timings'].mean()
avg_E4 = df.loc[df['E_Floor'] == 4, 'E_Timings'].mean()
avg_E5 = df.loc[df['E_Floor'] == 5, 'E_Timings'].mean()
avg_E6 = df.loc[df['E_Floor'] == 6, 'E_Timings'].mean()
avg_E7 = df.loc[df['E_Floor'] == 7, 'E_Timings'].mean()
avg_E8 = df.loc[df['E_Floor'] == 8, 'E_Timings'].mean()
avg_E9 = df.loc[df['E_Floor'] == 9, 'E_Timings'].mean()
avg_E10 = df.loc[df['E_Floor'] == 10, 'E_Timings'].mean()
fixed_E = df['E_Fixed'].mean()
avg_cap_E = df['E_Lift_capacity'].mean()



#average data for lift F
avg_F1 = df.loc[df['F_Floor'] == 2, 'F_Timings'].mean()
avg_F2 = df.loc[df['F_Floor'] == 4, 'F_Timings'].mean()
avg_F3 = df.loc[df['F_Floor'] == 6, 'F_Timings'].mean()
avg_F4 = df.loc[df['F_Floor'] == 8, 'F_Timings'].mean()
avg_F5 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
avg_F6 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
avg_F7 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
avg_F8 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
avg_F9 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
avg_F10 = df.loc[df['F_Floor'] == 9, 'F_Timings'].mean()
fixed_F = df['F_Fixed'].mean()
avg_cap_F = df['F_Lift_capacity'].mean()



#entering queue data 
queue_A=int(input("Enter queue data for lift A"))
queue_B=int(input("Enter queue data for lift B"))
queue_C=int(input("Enter queue data for lift C"))
queue_D=int(input("Enter queue data for lift D"))
queue_E=int(input("Enter queue data for lift E"))
queue_F=int(input("Enter queue data for lift F"))

#entering target floor
t_floor=input("Enter Target Floor")

#Calculations
if t_floor=='1':    
    if queue_B>avg_cap_B:
        avg_B1 = avg_B1+fixed_B
        print("average time of B",avg_B1)
    if queue_D>avg_cap_D :
        avg_D1 = avg_D1+fixed_D
        print("average time of D",avg_D1)
    if queue_E>avg_cap_E :
        avg_E1 = avg_E1+fixed_E
        print("average time of E",avg_E1)
    if queue_F>avg_cap_F :
        avg_F1 = avg_F1+fixed_F
        print("average time of F",avg_F1)
    smallest1 = min(avg_B1,avg_D1,avg_E1,avg_F1)
    print(smallest1)
    
    if smallest1==avg_B1 :
        print("Preferable Elevator = B")
    elif smallest1==avg_D1 :
        print("Preferable Elevator = D")
    elif smallest1==avg_E1 :
        print("Preferable Elevator = E")
    elif smallest1==avg_F1 :
        print("Preferable Elevator = F")        

    
if t_floor=='2':
    if queue_A>avg_cap_A :
        avg_A2 = avg_A2+fixed_A
        print("average time of A",avg_A2)
    if queue_C>avg_cap_C :
        avg_C2 = avg_C2+fixed_C
        print("average time of C",avg_C2)
    if queue_E>avg_cap_E :
        avg_E2 = avg_E2+fixed_E
        print("average time of E",avg_E2)
    if queue_F>avg_cap_F :
        avg_F2 = avg_F2+fixed_F
        print("average time of F",avg_F2)
    smallest2 = min(avg_A2,avg_C2,avg_E2,avg_F2)
    print(smallest2)
    
    if smallest2==avg_A2 :
        print("Preferable Elevator = A")
    elif smallest2==avg_C2 :
        print("Preferable Elevator = C")
    elif smallest2==avg_E2 :
        print("Preferable Elevator = E")
    elif smallest2==avg_F2 :
        print("Preferable Elevator = F") 

        
if t_floor=='3':
    if queue_B>avg_cap_B :
        avg_B3 = avg_B3+fixed_B
        print("average time of B",avg_B3)
    if queue_D>avg_cap_D :
        avg_D3 = avg_D3+fixed_D
        print("average time of D",avg_D3)
    if queue_E>avg_cap_E :
        avg_E3 = avg_E3+fixed_E
        print("average time of E",avg_E3)
    if queue_F>avg_cap_F :
        avg_F3 = avg_F3+fixed_F
        print("average time of F",avg_F3)
    smallest3 = min(avg_B3,avg_D3,avg_E3,avg_F3)
    print(smallest3)
    
    if smallest3==avg_B3 :
        print("Preferable Elevator = B")
    elif smallest3==avg_D3 :
        print("Preferable Elevator = D")
    elif smallest3==avg_E3 :
        print("Preferable Elevator = E")
    elif smallest3==avg_F3 :
        print("Preferable Elevator = F")

        
if t_floor=='4':
    if queue_A>avg_cap_A :
        avg_A4 = avg_A4+fixed_A
        print("average time of A",avg_A4)
    if queue_C>avg_cap_C :
        avg_C4 = avg_C4+fixed_C
        print("average time of C",avg_C4)
    if queue_E>avg_cap_E :
        avg_E4 = avg_E4+fixed_E
        print("average time of E",avg_E4)
    if queue_F>avg_cap_F :
        avg_F4 = avg_F4+fixed_F
        print("average time of F",avg_F4)
    smallest4 = min(avg_A4,avg_C4,avg_E4,avg_F4)
    print(smallest4)
    
    if smallest4==avg_A4:
        print("Preferable Elevator = A")
    elif smallest4==avg_C4:
        print("Preferable Elevator = C")
    elif smallest4==avg_E4:
        print("Preferable Elevator = E")
    elif smallest4==avg_F4:
        print("Preferable Elevator = F")

    
if t_floor=='5':
    if queue_B>avg_cap_B:
        avg_B5 = avg_B5+fixed_B
        print("average time of B",avg_B5)
    if queue_D>avg_cap_D:
        avg_D5 = avg_D5+fixed_D
        print("average time of D",avg_D5)
    if queue_E>avg_cap_E:
        avg_E5 = avg_E5+fixed_E
        print("average time of E",avg_E5)
    if queue_F>avg_cap_F:
        avg_F5 = avg_F5+fixed_F
        print("average time of F",avg_F5)
    smallest5 = min(avg_B5,avg_D5,avg_E5,avg_F5)
    print(smallest5)
    
    if smallest5==avg_B5:
        print("Preferable Elevator = B")
    elif smallest5==avg_D5:
        print("Preferable Elevator = D")
    elif smallest5==avg_E5:
        print("Preferable Elevator = E")
    elif smallest5==avg_F5:
        print("Preferable Elevator = F")

        
if t_floor=='6':
    if queue_A>avg_cap_A:
        avg_A6 = avg_A6+fixed_A
        print("average time of A",avg_A6)
    if queue_C>avg_cap_C:
        avg_C6 = avg_C6+fixed_C
        print("average time of C",avg_C6)
    if queue_E>avg_cap_E:
        avg_E6 = avg_E6+fixed_E
        print("average time of E",avg_E6)
    if queue_F>avg_cap_F:
        avg_F6 = avg_F6+fixed_F
        print("average time of F",avg_F6)
    smallest6 = min(avg_A6,avg_C6,avg_E6,avg_F6)
    print(smallest6)
    
    if smallest6==avg_A6:
        print("Preferable Elevator = A")
    elif smallest6==avg_C6:
        print("Preferable Elevator = C")
    elif smallest6==avg_E6:
        print("Preferable Elevator = E")
    elif smallest6==avg_F6:
        print("Preferable Elevator = F")

    
if t_floor=='7':
    if queue_B>avg_cap_B:
        avg_B7 = avg_B7+fixed_B
        print("average time of B",avg_B7)
    if queue_D>avg_cap_D:
        avg_D7 = avg_D7+fixed_D
        print("average time of D",avg_D7)
    if queue_E>avg_cap_E:
        avg_E7 = avg_E7+fixed_E
        print("average time of E",avg_E7)
    if queue_F>avg_cap_F:
        avg_F7 = avg_F7+fixed_F
        print("average time of F",avg_F7)

    smallest7 = min(avg_B7,avg_D7,avg_E7,avg_F7)
    print(smallest7)
    
    if smallest7==avg_B7:
        print("Preferable Elevator = B")
    elif smallest7==avg_D7:
        print("Preferable Elevator = D")
    elif smallest7==avg_E7:
        print("Preferable Elevator = E")
    elif smallest7==avg_F7:
        print("Preferable Elevator = F")
        
if t_floor=='8':
    if queue_A>avg_cap_A:
        avg_A8 = avg_A8+fixed_A
        print("average time of A",avg_A8)
    if queue_C>avg_cap_C:
        avg_C8 = avg_C8+fixed_C
        print("average time of C",avg_C8)
    if queue_E>avg_cap_E:
        avg_E8 = avg_E8+fixed_E
        print("average time of E",avg_E8)
    if queue_F>avg_cap_F:
        avg_F8 = avg_F8+fixed_F
        print("average time of F",avg_F8)
    smallest8 = min(avg_A8,avg_C8,avg_E8,avg_F8)
    print(smallest8)
    
    if smallest8==avg_A8:
        print("Preferable Elevator = A")
    elif smallest8==avg_C8:
        print("Preferable Elevator = C")
    elif smallest8==avg_E8:
        print("Preferable Elevator = E")
    elif smallest8==avg_F8:
        print("Preferable Elevator = F")

        
if t_floor=='9':
    if queue_A>avg_cap_A:
        avg_A9 = avg_A9+fixed_A
        print("average time of A",avg_A9)
    if queue_B>avg_cap_B:
        avg_B9 = avg_B9+fixed_B
        print("average time of B",avg_B9)
    if queue_C>avg_cap_C:
        avg_C9 = avg_C9+fixed_C
        print("average time of C",avg_C9)
    if queue_D>avg_cap_D:
        avg_D9 = avg_D9+fixed_D
        print("average time of D",avg_D9)
    if queue_F>avg_cap_E:
        avg_E9 = avg_E9+fixed_E
        print("average time of E",avg_E9)
    if queue_F>avg_cap_F:
        avg_F9 = avg_F9+fixed_F
        print("average time of F",avg_F9)
    smallest9 = min(avg_A9,avg_B9,avg_C9,avg_D9,avg_E9,avg_F9)
    print(smallest9)
    
    if smallest9==avg_A9:
        print("Preferable Elevator = A")
    elif smallest9==avg_B9:
        print("Preferable Elevator = B")
    elif smallest9==avg_C9:
        print("Preferable Elevator = C")
    elif smallest9==avg_D9:
        print("Preferable Elevator = D")
    elif smallest9==avg_E9:
        print("Preferable Elevator = E")
    elif smallest9==avg_F9:
        print("Preferable Elevator = F")        

        
if t_floor=='10':
    if queue_F>avg_cap_E:
        avg_E10 = avg_F10+fixed_E
        print("average time of E",avg_E10)
    if queue_F>avg_cap_F:
        avg_F10 = avg_F10+fixed_F
        print("average time of F",avg_F10)
    smallest10 = min(avg_E10,avg_F10)
    print(smallest10)
    
    if smallest10==avg_E10:
        print("Preferable Elevator = E")
    elif smallest10==avg_F10:
        print("Preferable Elevator = F")
# Out:
# Enter queue data for lift A 10
# Enter queue data for lift B 7
# Enter queue data for lift C 12
# Enter queue data for lift D 6
# Enter queue data for lift E 16
# Enter queue data for lift F 22
# Enter Target Floor 8
# average time of A 275.0
# average time of C 224.73333333333335
# average time of F 264.2
# 73.2
# Preferable Elevator = E
